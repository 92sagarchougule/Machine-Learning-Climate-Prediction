# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
df = pd.read_excel('Seasonal_Precipitation.xlsx','Ratnagiri')
df
# Out:
#     YEAR  PRECIPITATION
# 0   1988      27.268033
# 1   1989      27.834426
# 2   1990      23.064754
# 3   1991      24.214876
# 4   1992      25.941803
# 5   1993      28.395833
# 6   1994      19.672131
# 7   1995      22.638525
# 8   1996      24.683607
# 9   1997      23.875410
# 10  1998      27.714050
# 11  1999      19.234426
# 12  2000      25.173333
# 13  2001      17.481967
# 14  2002      21.663115
# 15  2003      20.336885
# 16  2004      22.974590
# 17  2005      24.980165
# 18  2006      24.696739
# 19  2007      30.763333
# 20  2008      19.088043
# 21  2009      23.108264
# 22  2010      30.270000
# 23  2011      35.518852
# 24  2012      26.139496
# 25  2013      25.097521
# 26  2014      20.734167
# 27  2015      18.271074
# 28  2016      33.069421
# 29  2017      22.966292
# 30  2018      25.417213

# %%
plt.figure(figsize=(9,5))
plt.title('Seasonal Precipitation of Ratnagiri District (June to September)')
plt.xlabel('[ Years ]')
plt.ylabel('[ In Millimetres (mm) ]')
plt.plot(df.YEAR,df.PRECIPITATION,label='Precipitation',color='g')
plt.legend(loc=1)
plt.grid(color='gray', linestyle='-', linewidth=0.4)
plt.savefig('Seasonal Precipitation (1988 to 2018).png',transparant=True,b_boxinches='tight', dpi=350)

# %% [markdown]
# # Model

# %%
reg = linear_model.LinearRegression()

# %%
df1 = pd.read_csv('Year_to_predicted_rainfall.csv')
df1.head()
# Out:
#    YEAR
# 0  2019
# 1  2020
# 2  2021
# 3  2022
# 4  2023

# %% [markdown]
# # Precipitation = M * Year + B

# %%
Pre_PRECIPITATION = reg.fit(df[['YEAR']],df.PRECIPITATION)
Precipitation = Pre_PRECIPITATION.predict(df1)

# %%
#M = reg.coef_

#Year = Year of Rainfall

#B = reg.intercept_

# %%
Pre_PRECIPITATION.coef_
# Out:
# array([0.03474445])

# %%
Pre_PRECIPITATION.intercept_
# Out:
# -45.00317996704446

# %%
df1['Pre_Precipitation'] = Precipitation

# %%
df1   #Predicted Rainfall Using Single Variable linear Regression
# Out:
#     YEAR  Pre_Precipitation
# 0   2019          25.145858
# 1   2020          25.180602
# 2   2021          25.215347
# 3   2022          25.250091
# 4   2023          25.284836
# 5   2024          25.319580
# 6   2025          25.354324
# 7   2026          25.389069
# 8   2027          25.423813
# 9   2028          25.458558
# 10  2030          25.528047
# 11  2031          25.562791
# 12  2032          25.597536
# 13  2033          25.632280
# 14  2034          25.667025
# 15  2035          25.701769
# 16  2036          25.736513
# 17  2037          25.771258
# 18  2038          25.806002
# 19  2039          25.840747
# 20  2040          25.875491
# 21  2041          25.910236
# 22  2042          25.944980
# 23  2043          25.979725
# 24  2044          26.014469
# 25  2046          26.083958
# 26  2047          26.118702
# 27  2048          26.153447
# 28  2049          26.188191
# 29  2050          26.222936

# %%
plt.figure(figsize=(9,5))
plt.title('Prediction of Seasonal Precipitation of Ratnagiri District (June to September)')
plt.xlabel('Years')
plt.ylabel('[ In Millimetres (mm) ]')
plt.plot(df.YEAR,df.PRECIPITATION,label='Precipitation',color='g')
plt.plot(df1.YEAR,df1.Pre_Precipitation,'--r',label='Predicted Precipitation',color='g')
plt.legend(loc=1)
plt.grid(color='gray', linestyle='-', linewidth=0.4)
plt.savefig('Prediction of Seasonal Precipitation (Next 30 year).png',transparant=True,b_boxinches='tight', dpi=350)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
df = pd.read_excel('Seasonal_Precipitation.xlsx','Raigad')
df
# Out:
#     YEAR  PRECIPITATION
# 0   1988      17.743443
# 1   1989      15.231405
# 2   1990      22.257377
# 3   1991      21.433607
# 4   1992      14.400000
# 5   1993      21.509016
# 6   1994      17.483607
# 7   1995      11.120492
# 8   1996      17.557377
# 9   1997      15.488525
# 10  1998      16.630000
# 11  1999      14.788361
# 12  2000      19.743444
# 13  2001      12.488525
# 14  2002      12.000820
# 15  2003      18.369672
# 16  2004      21.689344
# 17  2005      20.921739
# 18  2006      16.429752
# 19  2007      25.716807
# 20  2008      17.786066
# 21  2012      14.163636
# 22  2013      16.804918
# 23  2014      17.565574
# 24  2015      13.076033
# 25  2018      16.187705

# %%
plt.figure(figsize=(9,5))
plt.title('Seasonal Precipitation of Raigad District (June to September)')
plt.xlabel('[ Years ]')
plt.ylabel('[ In Millimetres (mm) ]')
plt.plot(df.YEAR,df.PRECIPITATION,label='Precipitation',color='g')
plt.legend(loc=1)
plt.grid(color='gray', linestyle='-', linewidth=0.4)
plt.savefig('Seasonal Precipitation (1988 to 2018).png',transparant=True,b_boxinches='tight', dpi=350)

# %% [markdown]
# # Model

# %%
reg = linear_model.LinearRegression()

# %%
df1 = pd.read_csv('Year_to_predicted_rainfall.csv')
df1.head()
# Out:
#    YEAR
# 0  2019
# 1  2020
# 2  2021
# 3  2022
# 4  2023

# %% [markdown]
# # Precipitation = M * Year + B

# %%
Pre_PRECIPITATION = reg.fit(df[['YEAR']],df.PRECIPITATION)
Precipitation = Pre_PRECIPITATION.predict(df1)

# %%
#M = reg.coef_

#Year = Year of Rainfall

#B = reg.intercept_

# %%
Pre_PRECIPITATION.coef_
# Out:
# array([-0.04199437])

# %%
Pre_PRECIPITATION.intercept_
# Out:
# 101.29055690258295

# %%
df1['Pre_Precipitation'] = Precipitation

# %%
df1   #Predicted Rainfall Using Single Variable linear Regression
# Out:
#     YEAR  Pre_Precipitation
# 0   2019          16.503917
# 1   2020          16.461923
# 2   2021          16.419929
# 3   2022          16.377934
# 4   2023          16.335940
# 5   2024          16.293946
# 6   2025          16.251951
# 7   2026          16.209957
# 8   2027          16.167962
# 9   2028          16.125968
# 10  2030          16.041979
# 11  2031          15.999985
# 12  2032          15.957991
# 13  2033          15.915996
# 14  2034          15.874002
# 15  2035          15.832007
# 16  2036          15.790013
# 17  2037          15.748019
# 18  2038          15.706024
# 19  2039          15.664030
# 20  2040          15.622036
# 21  2041          15.580041
# 22  2042          15.538047
# 23  2043          15.496052
# 24  2044          15.454058
# 25  2046          15.370069
# 26  2047          15.328075
# 27  2048          15.286081
# 28  2049          15.244086
# 29  2050          15.202092

# %%
plt.figure(figsize=(9,5))
plt.title('Prediction of Seasonal Precipitation of Raigad District (June to September)')
plt.xlabel('Years')
plt.ylabel('[ In Millimetres (mm) ]')
plt.plot(df.YEAR,df.PRECIPITATION,label='Precipitation',color='g')
plt.plot(df1.YEAR,df1.Pre_Precipitation,'--r',label='Predicted Precipitation',color='g')
plt.legend(loc=1)
plt.grid(color='gray', linestyle='-', linewidth=0.4)
plt.savefig('Prediction of Seasonal Precipitation (Next 30 year).png',transparant=True,b_boxinches='tight', dpi=350)
